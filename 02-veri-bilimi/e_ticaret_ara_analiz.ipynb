# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veri = pd.read_csv("e_ticaret_veri_seti.csv")

# %% [markdown]
# ##### **Soru 1 -- Veri setini yükleyin ve ilk 10 satırı ile son 10 satırını ekrana yazdırın.**

# %%
veri.head(10)
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 5  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 6  SIP101351    MUS1011  2025-02-27 11:35:00   İstanbul            Marmara
# 7  SIP101172    MUS1357  2024-07-22 13:26:00     Ankara         İç Anadolu
# 8  SIP100779    MUS1354  2025-12-05 11:19:00   İstanbul            Marmara
# 9  SIP100202    MUS1067  2024-05-11 22:53:00      Bursa            Marmara
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# ...

# %%
veri.tail(10)
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1418  SIP100056    MUS1238  2024-04-19 20:27:00     Ankara         İç Anadolu
# 1419  SIP101279    MUS1149  2024-08-24 08:38:00     Ankara         İç Anadolu
# 1420  SIP100920    MUS1425  2025-07-04 14:58:00      İzmir                Ege
# 1421  SIP100480    MUS1323  2024-06-20 20:34:00     Ankara         İç Anadolu
# 1422  SIP101222    MUS1440  2025-05-14 09:21:00      Bursa            Marmara
# 1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1424  SIP101193    MUS1297  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu
# 1425  SIP101210    MUS1122  2025-03-07 09:07:00        NaN            Marmara
# 1426  SIP101060    MUS1189  2025-04-19 21:52:00    Kocaeli            Marmara
# 1427  SIP100642    MUS1289  2024-09-22 16:36:00     Ankara         İç Anadolu
#
#          kategori           urun_adi  adet  birim_fiyat  indirim_orani  \
# ...

# %% [markdown]
# **Yorum:** Veri setinin ilk ve son 10 satırı incelendiğinde; sipariş, müşteri, tarih, şehir, kategori, ürün, fiyat, ödeme ve müşteri puanı gibi farklı türlerde değişkenlerin bulunduğu görülmektedir.

# %% [markdown]
# ##### **Soru 2 -- Veri setinin satır sayısını, sütun sayısını ve tüm sütun isimlerini ekrana yazdırın.**

# %%
veri.shape[0]
# Out:
# 1428

# %%
veri.shape[1]
# Out:
# 18

# %%
veri.columns
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'adet', 'birim_fiyat', 'indirim_orani',
#        'kargo_ucreti', 'odeme_turu', 'musteri_tipi', 'teslimat_gunu',
#        'musteri_puani', 'iade_durumu', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %% [markdown]
# **Yorum:** Veri setinde toplam 1.428 gözlem ve 18 değişken bulunmaktadır. Değişkenler; sipariş ve müşteri bilgileri, tarih, konum, kategori, ürün, fiyat, ödeme yöntemi, müşteri tipi, teslimat süresi ve müşteri puanı gibi farklı özellikleri kapsamaktadır. Bu yapı, veri setinin hem kategorik hem de sayısal değişkenler açısından çeşitli analizler için uygun olduğunu göstermektedir.

# %% [markdown]
# ##### **Soru 3 -- info() ve describe() çıktılarını alın. Ardından veri setindeki sayısal sütunları ve kategorik sütunları ayrı ayrı listeleyin.**

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   siparis_id       1428 non-null   object
#  1   musteri_id       1428 non-null   object
#  2   siparis_tarihi   1428 non-null   object
#  3   sehir            1403 non-null   object
#  4   bolge            1428 non-null   object
#  5   kategori         1428 non-null   object
#  6   urun_adi         1428 non-null   object
#  7   adet             1428 non-null   int64
#  8   birim_fiyat      1428 non-null   float64
#  9   indirim_orani    1412 non-null   float64
#  10  kargo_ucreti     1428 non-null   float64
#  11  odeme_turu       1393 non-null   object
#  12  musteri_tipi     1386 non-null   object
#  13  teslimat_gunu    1400 non-null   float64
#  14  musteri_puani    1372 non-null   float64
#  15  iade_durumu      1428 non-null   object
# ...

# %%
veri.describe()
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1428.000000   1428.000000    1412.000000   1428.000000    1400.000000
# mean      2.136555    658.477654       0.052054     39.725140       3.370714
# std       2.015770   1042.414639       0.060115     14.185017       1.825990
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    199.185000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    819.177500       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar
# count    1372.000000      1428.000000   1428.000000
# mean        4.002187         0.302799   1370.590336
# std         1.096707         0.069795   2961.689500
# min         0.000000         0.180000     89.680000
# ...

# %%
sayisal_sütunlar = veri.select_dtypes(include=["number"]).columns

sayisal_sütunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
kategorik_sütunlar = veri.select_dtypes(include=["object"]).columns

kategorik_sütunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %% [markdown]
# **Yorum:** Veri setinde 8 sayısal ve 10 kategorik değişken bulunmaktadır. info() çıktısına göre bazı sütunlarda eksik değerler olduğu görülmektedir. Ayrıca siparis_tarihi sütununun object veri tipinde olması, ilerleyen adımlarda tarih formatına dönüştürülmesi gerektiğini göstermektedir. Sayısal değişkenlerin temel istatistikleri incelendiğinde değişkenlerin değer aralıklarının birbirinden farklı olduğu görülmektedir.

# %% [markdown]
# ##### **Soru 4 -- Her sütundaki eksik değer sayısını hesaplayın. Sonra eksik veri oranlarını yüzde olarak çıkarın ve eksik veri oranı en yüksek 5 sütunu yazdırın.**

# %%
veri.isnull().sum()
# Out:
# siparis_id          0
# musteri_id          0
# siparis_tarihi      0
# sehir              25
# bolge               0
# kategori            0
# urun_adi            0
# adet                0
# birim_fiyat         0
# indirim_orani      16
# kargo_ucreti        0
# odeme_turu         35
# musteri_tipi       42
# teslimat_gunu      28
# musteri_puani      56
# iade_durumu         0
# kar_marji_orani     0
# toplam_tutar        0
# dtype: int64

# %%
veri.isnull().sum() / len(veri) * 100
# Out:
# siparis_id         0.000000
# musteri_id         0.000000
# siparis_tarihi     0.000000
# sehir              1.750700
# bolge              0.000000
# kategori           0.000000
# urun_adi           0.000000
# adet               0.000000
# birim_fiyat        0.000000
# indirim_orani      1.120448
# kargo_ucreti       0.000000
# odeme_turu         2.450980
# musteri_tipi       2.941176
# teslimat_gunu      1.960784
# musteri_puani      3.921569
# iade_durumu        0.000000
# kar_marji_orani    0.000000
# toplam_tutar       0.000000
# dtype: float64

# %%
((veri.isnull().sum() / len(veri)) * 100).sort_values(ascending=False).head(5)
# Out:
# musteri_puani    3.921569
# musteri_tipi     2.941176
# odeme_turu       2.450980
# teslimat_gunu    1.960784
# sehir            1.750700
# dtype: float64

# %% [markdown]
# **Yorum:** Veri setinde en fazla eksik değer 56 kayıt ile musteri_puani sütununda bulunmaktadır. Bunu 42 eksik değer ile musteri_tipi, 35 ile odeme_turu, 28 ile teslimat_gunu ve 25 ile sehir sütunları takip etmektedir. Eksik veri oranlarının tüm sütunlarda %4'ün altında olduğu görülmektedir. Bu nedenle eksik değerlerin veri setinden tamamen silinmesi yerine, uygun yöntemlerle tamamlanması tercih edilebilir.

# %% [markdown]
# ##### **Soru 5 -- En az bir eksik değer içeren satırları filtreleyin ve bu satırlardan ilk 20 tanesini ekrana yazdırın.**

# %%
veri[veri.isnull().any(axis=1)].head(20)
# Out:
#     siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 19   SIP100677    MUS1148  2024-07-11 16:24:00      Adana            Akdeniz
# 33   SIP101126    MUS1406  2024-09-11 20:05:00     Mersin            Akdeniz
# 50   SIP101040    MUS1386  2025-04-01 09:30:00    Trabzon          Karadeniz
# 60   SIP100890    MUS1271  2024-11-07 19:47:00      İzmir                Ege
# 61   SIP101317    MUS1060  2024-09-05 20:49:00        NaN            Akdeniz
# 70   SIP100715    MUS1033  2024-11-10 21:50:00   İstanbul            Marmara
# 82   SIP100807    MUS1431  2025-01-07 14:12:00     Ankara         İç Anadolu
# 84   SIP100679    MUS1310  2024-05-20 18:51:00      İzmir                Ege
# 86   SIP101071    MUS1131  2024-09-18 12:24:00        NaN         İç Anadolu
# 92   SIP101366    MUS1347  2025-03-04 14:00:00      Bursa            Marmara
# 96   SIP101067    MUS1337  2025-06-02 12:23:00  Gaziantep  Güneydoğu Anadolu
# ...

# %% [markdown]
# **Yorum:** En az bir eksik değer içeren kayıtların ilk 20 satırı incelendiğinde, eksik değerlerin musteri_puani, musteri_tipi, indirim_orani, sehir, odeme_turu ve teslimat_gunu gibi farklı sütunlarda bulunduğu görülmektedir. Bazı kayıtlarda birden fazla eksik değer bulunurken, bazı kayıtlarda yalnızca tek bir sütunda eksiklik bulunmaktadır. Bu nedenle sonraki adımlarda eksik değerler ilgili değişkenlerin veri türlerine ve yapısına uygun yöntemlerle tamamlanacaktır.

# %% [markdown]
# ##### **Soru 6 -- indirim_orani ve musteri_puani sütunlarındaki eksik değerleri medyan ile doldurun. Doldurmadan önce ve sonra bu iki sütundaki eksik değer sayılarını karşılaştırın.**

# %%
veri[["indirim_orani", "musteri_puani"]].isnull().sum()
# Out:
# indirim_orani    16
# musteri_puani    56
# dtype: int64

# %%
veri[["indirim_orani" , "musteri_puani"]].median()
# Out:
# indirim_orani    0.05
# musteri_puani    4.00
# dtype: float64

# %%
veri["indirim_orani"].fillna(veri["indirim_orani"].median(), inplace=True)
veri["musteri_puani"].fillna(veri["musteri_puani"].median(), inplace=True)
# Out:
# /tmp/ipykernel_684/2266941631.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   veri["indirim_orani"].fillna(veri["indirim_orani"].median(), inplace=True)
# /tmp/ipykernel_684/2266941631.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
veri[["indirim_orani", "musteri_puani"]].isnull().sum()
# Out:
# indirim_orani    0
# musteri_puani    0
# dtype: int64

# %% [markdown]
# **Yorum:** indirim_orani sütunundaki 16 eksik değer 0.05 medyan değeriyle, musteri_puani sütunundaki 56 eksik değer ise 4.00 medyan değeriyle doldurulmuştur. Doldurma işlemi sonrasında her iki sütunda da eksik değer kalmadığı görülmüştür. Sayısal değişkenlerde medyan kullanılması, özellikle uç değerlerden ortalamaya göre daha az etkilenmesi nedeniyle tercih edilmiştir.

# %% [markdown]
# ##### **Soru 7 -- odeme_turu ve musteri_tipi sütunlarındaki eksik değerleri mod ile doldurun. Daha sonra bu sütunlarda eksik değer kalıp kalmadığını kontrol edin.**

# %%
veri[["odeme_turu", "musteri_tipi"]].isnull().sum()
# Out:
# odeme_turu      35
# musteri_tipi    42
# dtype: int64

# %%
veri[["odeme_turu", "musteri_tipi"]].mode()
# Out:
#     odeme_turu musteri_tipi
# 0  Kredi Kartı       Mevcut

# %%
veri["odeme_turu"].fillna(veri["odeme_turu"].mode()[0], inplace=True)
veri["musteri_tipi"].fillna(veri["musteri_tipi"].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_684/2981552361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   veri["odeme_turu"].fillna(veri["odeme_turu"].mode()[0], inplace=True)
# /tmp/ipykernel_684/2981552361.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
veri[["odeme_turu", "musteri_tipi"]].isnull().sum()
# Out:
# odeme_turu      0
# musteri_tipi    0
# dtype: int64

# %% [markdown]
# **Yorum:** odeme_turu sütunundaki 35 eksik değer en sık tekrar eden değer olan Kredi Kartı, musteri_tipi sütunundaki 42 eksik değer ise Mevcut değeri ile doldurulmuştur. Doldurma işlemi sonrasında her iki sütunda da eksik değer kalmadığı görülmüştür. Kategorik değişkenlerde eksik değerlerin mod ile doldurulması, mevcut kategorik dağılımın korunması açısından uygun bir yöntemdir.

# %% [markdown]
# ##### **Soru 8 -- siparis_tarihi sütununu datetime tipine dönüştürün. Ardından bu sütundan siparis_yili, siparis_ayi, siparis_gunu ve haftanin_gunu adında 4 yeni sütun üretin ve ilk 10 satırını gösterin.**

# %%
veri["siparis_tarihi"] = pd.to_datetime(veri["siparis_tarihi"])

# %%
veri["siparis_yili"] = veri["siparis_tarihi"].dt.year
veri["siparis_ayi"] = veri["siparis_tarihi"].dt.month
veri["siparis_gunu"] = veri["siparis_tarihi"].dt.day
veri["haftanin_gunu"] = veri["siparis_tarihi"].dt.day_name()

# %%
veri.head(10)
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066 2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 5  SIP100687    MUS1147 2025-08-09 08:42:00      Konya         İç Anadolu
# 6  SIP101351    MUS1011 2025-02-27 11:35:00   İstanbul            Marmara
# 7  SIP101172    MUS1357 2024-07-22 13:26:00     Ankara         İç Anadolu
# 8  SIP100779    MUS1354 2025-12-05 11:19:00   İstanbul            Marmara
# 9  SIP100202    MUS1067 2024-05-11 22:53:00      Bursa            Marmara
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  ...  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05  ...
# ...

# %% [markdown]
# **Yorum:** siparis_tarihi sütunu datetime veri tipine dönüştürülerek sipariş tarihinden yıl, ay, gün ve haftanın günü bilgileri elde edilmiştir. Böylece tarih bilgisi ayrı değişkenlere ayrılarak sonraki analizlerde zaman bazlı incelemelerin yapılabilmesi sağlanmıştır.

# %% [markdown]
# ##### **Soru 9 -- Veri setindeki duplicate kayıt sayısını bulun. Duplicate kayıtları temizleyin ve temizlikten önce ve sonra veri setinin satır sayısını yazdırın.**

# %%
veri.duplicated().sum()
# Out:
# np.int64(28)

# %%
len(veri)
# Out:
# 1428

# %%
veri.drop_duplicates(inplace=True)

# %%
len(veri)
# Out:
# 1400

# %% [markdown]
# **Yorum:** Veri setinde 28 adet duplicate kayıt tespit edilmiştir. Duplicate kayıtların temizlenmesi sonucunda veri setinin satır sayısı 1428'den 1400'e düşmüştür. Böylece aynı kayıtların tekrar tekrar analiz sonuçlarını etkilemesi önlenmiştir.

# %% [markdown]
# ##### **Soru 10 -- sehir sütunundaki benzersiz değerleri inceleyin. İstanbul, istanbul, Istanbul gibi aynı anlama gelen farklı yazımları tek bir standart biçime dönüştürün. Temizlikten önce ve sonra benzersiz değer sayılarını karşılaştırın.**

# %%
veri["sehir"].value_counts(dropna=False)
# Out:
# sehir
# İstanbul     294
# Ankara       165
# İzmir        153
# Antalya      108
# Konya         87
# Bursa         86
# Adana         77
# Gaziantep     64
# Samsun        57
# Mersin        57
# Eskişehir     57
# Trabzon       55
# Kayseri       54
# Kocaeli       45
# NaN           25
# Istanbul       5
# istanbul       4
# ankara         4
# gaziantep      2
# Izmir          1
# Name: count, dtype: int64

# %%
veri["sehir"].nunique()
# Out:
# 19

# %%
veri["sehir"] = veri["sehir"].replace({
    "Istanbul": "İstanbul",
    "istanbul": "İstanbul",
    "ankara": "Ankara",
    "gaziantep": "Gaziantep",
    "Izmir": "İzmir"
})

# %%
veri["sehir"].nunique()
# Out:
# 14

# %%
veri["sehir"].value_counts(dropna=False)
# Out:
# sehir
# İstanbul     303
# Ankara       169
# İzmir        154
# Antalya      108
# Konya         87
# Bursa         86
# Adana         77
# Gaziantep     66
# Samsun        57
# Eskişehir     57
# Mersin        57
# Trabzon       55
# Kayseri       54
# Kocaeli       45
# NaN           25
# Name: count, dtype: int64

# %% [markdown]
# **Yorum:** sehir sütununda aynı şehirlerin farklı büyük-küçük harf ve karakter kullanımlarıyla kaydedildiği görülmüştür. Bu tutarsızlıkların giderilmesi sonucunda benzersiz şehir değeri 19'dan 14'e düşmüştür. Böylece aynı şehre ait kayıtlar tek bir standart kategori altında birleştirilerek şehir bazlı analizlerin daha doğru yapılması sağlanmıştır.

# %% [markdown]
# ##### **Soru 11 -- kategori sütunundaki tutarsız değerleri inceleyin. Örneğin Ev Yaşam, ev yaşam, ev&yaşam gibi farklı yazımları tek biçime dönüştürün. Temizlikten sonra value_counts() çıktısını yazdırın.**

# %%
veri["kategori"].value_counts(dropna=False)
# Out:
# kategori
# Kitap          245
# Elektronik     233
# Spor           223
# Ofis           219
# Kozmetik       218
# Ev ve Yaşam    213
# spor            12
# ofis            11
# kitap            8
# Elektronik       5
# kozmetık         4
# elektronik       3
# Kozmetik         3
# ev ve yaşam      2
# Ev&Yaşam         1
# Name: count, dtype: int64

# %%
veri["kategori"].nunique()
# Out:
# 15

# %%
veri["kategori"] = veri["kategori"].replace({
    "spor": "Spor",
    "ofis": "Ofis",
    "kitap": "Kitap",
    "elektronik": "Elektronik",
    "kozmetik": "Kozmetik",
    "kozmetık": "Kozmetik",
    "ev ve yaşam": "Ev ve Yaşam",
    "Ev&Yaşam": "Ev ve Yaşam"
})

# %%
veri["kategori"].value_counts()
# Out:
# kategori
# Kitap          253
# Elektronik     236
# Spor           235
# Ofis           230
# Kozmetik       222
# Ev ve Yaşam    216
# Elektronik       5
# Kozmetik         3
# Name: count, dtype: int64

# %%
veri["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'Ev ve Yaşam',
#        'Elektronik ', 'Kozmetik '], dtype=object)

# %%
veri["kategori"] = veri["kategori"].str.strip()

# %%
veri["kategori"].value_counts()
# Out:
# kategori
# Kitap          253
# Elektronik     241
# Spor           235
# Ofis           230
# Kozmetik       225
# Ev ve Yaşam    216
# Name: count, dtype: int64

# %% [markdown]
# **Yorum:** kategori sütununda büyük-küçük harf farklılıkları, Türkçe karakter farklılıkları ve değerlerin sonunda bulunan boşluklar nedeniyle tutarsız kayıtlar olduğu görülmüştür. Yapılan düzenlemeler sonucunda benzersiz kategori sayısı 15'ten 6'ya düşürülmüş ve tüm kayıtlar standart kategori adları altında birleştirilmiştir. Temizlik sonrasında en fazla kayıt Kitap kategorisinde, en az kayıt ise Ev ve Yaşam kategorisindedir.

# %% [markdown]
# ##### **Soru 12 -- Aşağıdaki koşullara uyan mantıksal olarak hatalı kayıtları bulun: birim_fiyat <= 0, toplam_tutar <= 0, teslimat_gunu < 0, musteri_puani > 5. Bu kayıtların sayısını yazdırın ve veri setinden çıkarın.**

# %%
hatalı_kayitlar = (
    (veri["birim_fiyat"] <= 0) |
    (veri["toplam_tutar"] <= 0) |
    (veri["teslimat_gunu"] < 0) |
    (veri["musteri_puani"] > 5)
)

# %%
hatalı_kayitlar.sum()
# Out:
# np.int64(2)

# %%
veri[hatalı_kayitlar]
# Out:
#      siparis_id musteri_id      siparis_tarihi     sehir    bolge  kategori  \
# 609   SIP100095    MUS1165 2025-10-12 21:31:00  İstanbul  Marmara  Kozmetik
# 1008  SIP101290    MUS1225 2024-01-16 21:46:00   Kocaeli  Marmara  Kozmetik
#
#                 urun_adi  adet  birim_fiyat  indirim_orani  ...  musteri_tipi  \
# 609              Şampuan     2       190.17           0.10  ...        Mevcut
# 1008  Yüz Temizleme Jeli     2       303.82           0.05  ...          Yeni
#
#      teslimat_gunu musteri_puani  iade_durumu  kar_marji_orani toplam_tutar  \
# 609            3.0           6.0        Hayır            0.416       342.31
# 1008           5.0           7.0         Evet            0.287       607.16
#
#       siparis_yili  siparis_ayi  siparis_gunu  haftanin_gunu
# 609           2025           10            12         Sunday
# 1008          2024            1            16        Tuesday
#
# [2 rows x 22 columns]

# %%
len(veri)
# Out:
# 1400

# %%
veri = veri[~hatalı_kayitlar]

# %%
len(veri)
# Out:
# 1398

# %% [markdown]
# **Yorum:** Veri setinde mantıksal olarak hatalı 2 kayıt tespit edilmiştir. Her iki kayıtta da musteri_puani değerinin 5'in üzerinde olduğu görülmüştür. Bu kayıtların veri setinden çıkarılması sonucunda gözlem sayısı 1400'den 1398'e düşürülmüştür.

# %% [markdown]
# ##### **Soru 13 -- birim_fiyat sütunu için IQR yöntemini kullanarak Q1, Q3, IQR, alt sınır ve üst sınır değerlerini hesaplayın. Sonra aykırı değer içeren kayıt sayısını yazdırın.**

# %%
Q1 = veri["birim_fiyat"].quantile(0.25)
Q3 = veri["birim_fiyat"].quantile(0.75)

IQR = Q3 - Q1

alt_sinir = Q1 - 1.5 * IQR
ust_sinir = Q3 + 1.5 * IQR

# %%
print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Alt sınır:", alt_sinir)
print("Üst sınır:", ust_sinir)
# Out:
# Q1: 198.85500000000002
# Q3: 817.335
# IQR: 618.48
# Alt sınır: -728.865
# Üst sınır: 1745.055

# %%
aykiri_deger_sayisi = (
    (veri["birim_fiyat"] < alt_sinir) |
    (veri["birim_fiyat"] > ust_sinir)
).sum()

aykiri_deger_sayisi
# Out:
# np.int64(92)

# %% [markdown]
# **Yorum:** birim_fiyat sütunu için IQR yöntemi uygulandığında Q1 değeri 198,855, Q3 değeri 817,335 ve IQR değeri 618,48 olarak hesaplanmıştır. Buna göre alt sınır -728,865, üst sınır ise 1745,055 olarak bulunmuştur. Bu sınırlar dışında kalan 92 kayıt aykırı değer olarak belirlenmiştir. Alt sınırın negatif olması nedeniyle aykırı değerlerin üst sınırın üzerinde yer aldığı görülmektedir.

# %% [markdown]
# ##### **Soru 14 -- toplam_tutar sütunu için histogram çizdirin ve box plot çizdirin. Ardından dağılım hakkında 2–3 cümlelik kısa bir yorum yazın.**

# %%
plt.figure(figsize=(8, 5))
plt.hist(veri["toplam_tutar"], bins=30)
plt.xlabel("Toplam Tutar")
plt.ylabel("Frekans")
plt.title("Toplam Tutar Dağılımı")
plt.show()

# %%
plt.figure(figsize=(8, 3))
plt.boxplot(veri["toplam_tutar"])
plt.xlabel("Toplam Tutar")
plt.title("Toplam Tutar Box Plot")
plt.show()

# %% [markdown]
# **Yorum:** toplam_tutar değişkeninin histogramı dağılımın sağa çarpık olduğunu ve kayıtların büyük bölümünün düşük toplam tutar aralıklarında yoğunlaştığını göstermektedir. Box plot incelendiğinde ise yüksek toplam tutara sahip çok sayıda aykırı değer bulunduğu görülmektedir. Bu nedenle toplam_tutar değişkeninin normal bir dağılım göstermediği ve bazı yüksek değerlerin dağılımı belirgin şekilde etkilediği söylenebilir.

# %% [markdown]
# ##### **Soru 15 -- Aşağıdaki analizleri yapın: kategori sütunu için value_counts() çıktısını yazdırın, musteri_tipi sütunu için yüzde dağılımı hesaplayın, odeme_turu sütunu için count plot çizdirin, birim_fiyat, toplam_tutar ve musteri_puani sütunlarının temel istatistiklerini çıkarın. Son olarak şu iki soruya cevap verin: Hangi kategori en yüksek ortalama toplam_tutar değerine sahip? Hangi müşteri tipi en yüksek ortalama musteri_puani değerine sahip?**

# %%
veri["kategori"].value_counts()
# Out:
# kategori
# Kitap          253
# Elektronik     241
# Spor           235
# Ofis           230
# Kozmetik       223
# Ev ve Yaşam    216
# Name: count, dtype: int64

# %%
veri["musteri_tipi"].value_counts(normalize=True) * 100
# Out:
# musteri_tipi
# Mevcut    49.499285
# Yeni      36.194564
# VIP       11.301860
# mevcut     1.645207
# yeni       0.929900
# vip        0.286123
# Vip        0.143062
# Name: proportion, dtype: float64

# %% [markdown]
# **Yorum:** musteri_tipi değişkeninde en yüksek pay %49,50 ile Mevcut müşterilere aittir. Bunu %36,19 ile Yeni ve %11,30 ile VIP müşteriler takip etmektedir. Ayrıca aynı müşteri tiplerinin farklı büyük-küçük harflerle yazıldığı kayıtlar bulunduğundan, yüzde dağılımı bu değerleri ayrı kategoriler olarak göstermektedir.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=veri, x="odeme_turu")
plt.xlabel("Ödeme Türü")
plt.ylabel("Sipariş Sayısı")
plt.title("Ödeme Türlerine Göre Sipariş Dağılımı")
plt.xticks(rotation=45)
plt.show()

# %%
veri["odeme_turu"].value_counts()
# Out:
# odeme_turu
# Kredi Kartı       706
# Banka Kartı       211
# Dijital Cüzdan    192
# Havale/EFT        141
# Kapıda Ödeme       95
# Kart               14
# banka karti        12
# kredi kartı         9
# dijital cüzdan      6
# Kapida Odeme        5
# Havale              4
# eft                 3
# Name: count, dtype: int64

# %% [markdown]
# **Yorum:** En çok tercih edilen ödeme yöntemi 706 sipariş ile Kredi Kartı olurken, bunu 211 sipariş ile Banka Kartı ve 192 sipariş ile Dijital Cüzdan takip etmektedir. Bununla birlikte aynı ödeme yöntemlerinin farklı yazımlarla (banka karti, kredi kartı, dijital cüzdan vb.) ayrı kategoriler olarak yer aldığı görülmektedir. Bu durum, kategorik verilerde standartlaştırmanın analiz sonuçlarının doğruluğu açısından önemli olduğunu göstermektedir.

# %%
veri[["birim_fiyat", "toplam_tutar", "musteri_puani"]].describe()
# Out:
#         birim_fiyat  toplam_tutar  musteri_puani
# count   1398.000000   1398.000000    1398.000000
# mean     660.712818   1377.934642       3.997854
# std     1051.014558   2988.042747       1.071193
# min       93.110000     89.680000       0.000000
# 25%      198.855000    327.190000       4.000000
# 50%      287.120000    670.965000       4.000000
# 75%      817.335000   1393.250000       5.000000
# max    18145.230000  63870.200000       5.000000

# %% [markdown]
# **Yorum:** birim_fiyat değişkeninin ortalaması 660,71, toplam_tutar değişkeninin ortalaması 1377,93 ve musteri_puani değişkeninin ortalaması 4,00'dır. toplam_tutar değişkeninde ortalama ile medyan arasındaki belirgin fark, yüksek tutarlı bazı işlemlerin dağılımı etkilediğini göstermektedir. musteri_puani değerlerinin ise 0 ile 5 arasında dağıldığı görülmektedir.

# %%
veri.groupby("kategori")["toplam_tutar"].mean().sort_values(ascending=False)
# Out:
# kategori
# Elektronik     3178.379876
# Spor           1411.789872
# Ofis           1266.854652
# Kozmetik        913.572332
# Ev ve Yaşam     869.912083
# Kitap           575.447628
# Name: toplam_tutar, dtype: float64

# %%
veri.groupby("musteri_tipi")["musteri_puani"].mean().sort_values(ascending=False)
# Out:
# musteri_tipi
# vip       4.500000
# mevcut    4.260870
# yeni      4.230769
# Yeni      4.003953
# Mevcut    4.002890
# VIP       3.905063
# Vip       2.500000
# Name: musteri_puani, dtype: float64

# %% [markdown]
# **Yorum:** Müşteri tipi bazında ortalama musteri_puani değerleri incelendiğinde, mevcut veri yazımları içerisinde vip müşteri tipi 4,50 ortalama ile en yüksek değere sahiptir. Ancak VIP, vip ve Vip değerlerinin aynı müşteri tipini ifade ettiği görülmektedir. Bu nedenle müşteri tipi değerleri standartlaştırıldığında sonuç değişebilir.

# %% [markdown]
# **Genel yorum:** Kategori dağılımında en fazla kayıt Kitap kategorisinde bulunurken, ödeme yöntemleri arasında Kredi Kartı en sık kullanılan yöntemdir. Sayısal değişkenler incelendiğinde toplam_tutar değişkeninin ortalama değerinin medyanından belirgin şekilde yüksek olması, yüksek tutarlı işlemlerin dağılımı etkilediğini göstermektedir. Kategori bazında en yüksek ortalama toplam_tutar değeri 3178,38 ile Elektronik kategorisine aittir. Müşteri tipi bazında ise mevcut yazımlar ayrı değerlendirildiğinde en yüksek ortalama musteri_puani değeri 4,50 ile vip grubunda görülmektedir.

# %% [markdown]
# ##### **Temizlenmiş veriyi yeni csv dosyası olarak kaydedelim**

# %%
veri.to_csv("temizlenmis_veri.csv", index=False, encoding="utf-8-sig")
